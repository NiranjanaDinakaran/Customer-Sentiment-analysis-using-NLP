# %%
import bs4
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url="https://www.airlinequality.com/airline-reviews/british-airways"
response=requests.get(url)
response.status_code
# Out:
# 200

# %%
soup=BeautifulSoup(response.text,'html5lib')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7 lt-ie10" lang="en-GB"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8 lt-ie10" lang="en-GB"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js lt-ie9 lt-ie10" lang="en-GB"> <![endif]-->
# <!--[if IE 9]>    <html class="no-js lt-ie10" lang="en-GB"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en-GB">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    British Airways Customer Reviews - SKYTRAX
#   </title>
#   <link as="image" data-rocket-preload="" fetchpriority="high" href="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/images/nav/grad-header.jpg" rel="preload"/>
#   <!-- Google Chrome Frame for IE -->
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <!-- mobile meta -->
#   <meta content="True" name="HandheldFriendly"/>
#   <meta content="320" name="MobileOptimized"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <!-- icons & favicons -->
#   <link href="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/images/apple-icon-touch.png" rel="apple-touch-icon"/>
#   <link href="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/favicon.png" rel="icon"/>
#   <!--[if IE]>
# 			<link rel="shortcut icon" href="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/favicon.ico">
# 		<![endif]-->
#   <meta content="#f01d4f" name="msapplication-TileColor"/>
#   <meta content="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/images/win8-tile-icon.png" name="msapplication-TileImage"/>
#   <link href="https://www.airlinequality.com/xmlrpc.php" rel="pingback"/>
#   <link href="https://fonts.googleapis.com/css?family=Source+Sans+Pro" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Montserrat:300,300i,500,700|Playfair+Display:400i,900" rel="stylesheet"/>
#   <script data-rocket-defer="" defer="" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/static_homepage_assets/js/static/modernizr-2.6.2.min.js">
#   </script>
#   <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
#   <style>
#    img:is([sizes="auto" i], [sizes^="auto," i]) { contain-intrinsic-size: 3000px 1500px }
#   </style>
#   <!-- This site is optimized with the Yoast SEO plugin v24.0 - https://yoast.com/wordpress/plugins/seo/ -->
#   <title>
#    British Airways Customer Reviews - SKYTRAX
#   </title>
#   <meta content="Read Verified British Airways customer reviews, view British Airways Photos, check customer ratings and opinions about British Airways standards." name="description"/>
#   <link href="https://www.airlinequality.com/airline-reviews/british-airways/" rel="canonical"/>
#   <link href="https://www.airlinequality.com/airline-reviews/british-airways/page/2/" rel="next"/>
#   <meta content="en_GB" property="og:locale"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Customer Reviews - SKYTRAX" property="og:title"/>
#   <meta content="Read Verified [name] customer reviews, view [name] Photos, check customer ratings and opinions about [name] standards." property="og:description"/>
#   <meta content="https://www.airlinequality.com/review_airline/" property="og:url"/>
#   <meta content="SKYTRAX" property="og:site_name"/>
#   <script class="yoast-schema-graph" type="application/ld+json">
#    {"@context":"https://schema.org","@graph":[{"@type":"CollectionPage","@id":"https://www.airlinequality.com/review_airline/","url":"https://www.airlinequality.com/review_airline/","name":"Customer Reviews - SKYTRAX","isPartOf":{"@id":"https://www.airlinequality.com/#website"},"description":"Read Verified [name] customer reviews, view [name] Photos, check customer ratings and opinions about [name] standards.","breadcrumb":{"@id":"https://www.airlinequality.com/review_airline/#breadcrumb"},"inLanguage":"en-GB"},{"@type":"BreadcrumbList","@id":"https://www.airlinequality.com/review_airline/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https://www.airlinequality.com/"},{"@type":"ListItem","position":2,"name":"Airline Reviews"}]},{"@type":"WebSite","@id":"https://www.airlinequality.com/#website","url":"https://www.airlinequality.com/","name":"SKYTRAX","description":"Air Travel Ratings &amp; Reviews | Airline Rating and Reviews | Airport Rating and Reviews | Seat Reviews","potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://www.airlinequality.com/?s={search_term_string}"},"query-input":{"@type":"PropertyValueSpecification","valueRequired":true,"valueName":"search_term_string"}}],"inLanguage":"en-GB"}]}
#   </script>
#   <!-- / Yoast SEO plugin. -->
#   <link href="//cdn.jsdelivr.net" rel="dns-prefetch"/>
#   <link href="https://www.airlinequality.com/wp-content/plugins/wp-google-search/wgs.css" id="wgs-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.airlinequality.com/wp-content/plugins/wp-google-search/wgs2.css" id="wgs2-css" media="all" rel="stylesheet" type="text/css"/>
#   <style id="wp-emoji-styles-inline-css" type="text/css">
#    img.wp-smiley, img.emoji {
# 		display: inline !important;
# 		border: none !important;
# 		box-shadow: none !important;
# 		height: 1em !important;
# 		width: 1em !important;
# 		margin: 0 0.07em !important;
# 		vertical-align: -0.1em !important;
# 		background: none !important;
# 		padding: 0 !important;
# 	}
#   </style>
#   <link href="https://www.airlinequality.com/wp-includes/css/dist/block-library/style.min.css" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
#   <style id="classic-theme-styles-inline-css" type="text/css">
#    /*! This file is auto-generated */
# .wp-block-button__link{color:#fff;background-color:#32373c;border-radius:9999px;box-shadow:none;text-decoration:none;padding:calc(.667em + 2px) calc(1.333em + 2px);font-size:1.125em}.wp-block-file__button{background:#32373c;color:#fff;text-decoration:none}
#   </style>
#   <style id="global-styles-inline-css" type="text/css">
#    :root{--wp--preset--aspect-ratio--square: 1;--wp--preset--aspect-ratio--4-3: 4/3;--wp--preset--aspect-ratio--3-4: 3/4;--wp--preset--aspect-ratio--3-2: 3/2;--wp--preset--aspect-ratio--2-3: 2/3;--wp--preset--aspect-ratio--16-9: 16/9;--wp--preset--aspect-ratio--9-16: 9/16;--wp--preset--color--black: #000000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #ffffff;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--font-size--small: 13px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36px;--wp--preset--font-size--x-large: 42px;--wp--preset--spacing--20: 0.44rem;--wp--preset--spacing--30: 0.67rem;--wp--preset--spacing--40: 1rem;--wp--preset--spacing--50: 1.5rem;--wp--preset--spacing--60: 2.25rem;--wp--preset--spacing--70: 3.38rem;--wp--preset--spacing--80: 5.06rem;--wp--preset--shadow--natural: 6px 6px 9px rgba(0, 0, 0, 0.2);--wp--preset--shadow--deep: 12px 12px 50px rgba(0, 0, 0, 0.4);--wp--preset--shadow--sharp: 6px 6px 0px rgba(0, 0, 0, 0.2);--wp--preset--shadow--outlined: 6px 6px 0px -3px rgba(255, 255, 255, 1), 6px 6px rgba(0, 0, 0, 1);--wp--preset--shadow--crisp: 6px 6px 0px rgba(0, 0, 0, 1);}:where(.is-layout-flex){gap: 0.5em;}:where(.is-layout-grid){gap: 0.5em;}body .is-layout-flex{display: flex;}.is-layout-flex{flex-wrap: wrap;align-items: center;}.is-layout-flex > :is(*, div){margin: 0;}body .is-layout-grid{display: grid;}.is-layout-grid > :is(*, div){margin: 0;}:where(.wp-block-columns.is-layout-flex){gap: 2em;}:where(.wp-block-columns.is-layout-grid){gap: 2em;}:where(.wp-block-post-template.is-layout-flex){gap: 1.25em;}:where(.wp-block-post-template.is-layout-grid){gap: 1.25em;}.has-black-color{color: var(--wp--preset--color--black) !important;}.has-cyan-bluish-gray-color{color: var(--wp--preset--color--cyan-bluish-gray) !important;}.has-white-color{color: var(--wp--preset--color--white) !important;}.has-pale-pink-color{color: var(--wp--preset--color--pale-pink) !important;}.has-vivid-red-color{color: var(--wp--preset--color--vivid-red) !important;}.has-luminous-vivid-orange-color{color: var(--wp--preset--color--luminous-v ...
# :where(.wp-block-post-template.is-layout-flex){gap: 1.25em;}:where(.wp-block-post-template.is-layout-grid){gap: 1.25em;}
# :where(.wp-block-columns.is-layout-flex){gap: 2em;}:where(.wp-block-columns.is-layout-grid){gap: 2em;}
# :root :where(.wp-block-pullquote){font-size: 1.5em;line-height: 1.6;}
#   </style>
#   <link href="https://www.airlinequality.com/wp-content/tablepress-combined.min.css" id="tablepress-default-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//cdn.jsdelivr.net/jquery.slick/1.3.11/slick.css" id="slick-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/css/style.css" id="joints-stylesheet-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/css/icons/foundation-icons.css" id="foundation-icons-css" media="all" rel="stylesheet" type="text/css"/>
#   <script id="jquery-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/vendor/jquery.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="modernizr-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/vendor/modernizr.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="picturefill-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/vendor/picturefill.min.js" type="text/javascript">
#   </script>
#   <link href="https://www.airlinequality.com/wp-json/" rel="https://api.w.org/"/>
#   <link href="https://www.airlinequality.com/wp-content/plugins/gendall-default/img/favicon.png" rel="icon" type="image/png"/>
#   <style id="wp-custom-css" type="text/css">
#    .home #main > section.layout-section.layout-2.border-top > div.col-content > div:nth-child(3), .home #main > section.layout-section.layout-2.border-top > div.col-content > div:nth-child(4) > section {
# 	display:none;
# }
#
# .captcha {
# 	float: none;
# 	text-align: left;
# 	margin-bottom: 20px;
# }
#
# #main > section .accordion-toggle {
# 	color: #f78152;
# 	background: none;
# 	font-size: 16px;
# 	margin: 10px 0 0 21px;
# }
# #main > section .accordion-toggle:hover {
# 	background: transparent;
# }
# #main > section .accordion-toggle .arrow-down {
# 	border-color: #f78152 transparent transparent transparent;
#
# }
#
# .home .button:not(.button-hero):not(.button-inverted), .new-button {
#   font-weight: 700;
#   padding: 0.67143em 0.87566em;
#   transition: background, color;
#   transition-duration: .2s;
#   cursor: pointer;
#   background: #0192d1;
#   display: block;
#   font-size: 1em;
#   text-decoration: none;
#   text-align: center;
#   padding: 12px 45px;
#   border: 2px solid #0192d1;
#   line-height: 1;
#   color: #ffffff; }
#   .home .button:not(.button-hero):not(.button-inverted):focus, .new-button:focus {
#     outline: none;
#     box-shadow: inset #77b255 0 0 0 0.2em; }
#   .home .button:not(.button-hero):not(.button-inverted):hover, .new-button:hover {
# 		text-decoration: none;
#     background: #ff6e3b;
#     border-color: #ff6e3b; }
#   .home .button:not(.button-hero):not(.button-inverted).cta {
#     border-radius: 0.13646em; }
#   .home .button:not(.button-hero):not(.button-inverted).submit-search {
#     padding: 0.87566em 2.89287em; }
#   .home .button:not(.button-hero):not(.button-inverted).centered {
#     width: 14em;
#     padding-right: 1.142em;
#     padding-left: 1.142em;
#     margin: 0 auto; }
#
# @media screen and (min-width: 700px) {
#     .new-button {
#       display: inline-block;
# 			font-size: 14px;
#     }
# }
#
#
# .home .button.button-inverted, .new-button.button-inverted {
#       background: #fff;
#       border: 2px solid #0192d1;
#       padding: 12px 45px;
#       color: #0192d1;
# }
#
# .home .button.button-inverted:hover, .new-button.button-inverted:hover {
#   background: #0192d1;
#   color: #fff;
# }
#
# @media screen and (min-width: 768px) {
# 	.new-buttons {
# 			margin-left: calc(1.1rem + 88px);
# 	}
# }
#
# .termly-styles-consent-banner-d8e726 .termly-styles-main-bdb6e9 p,
# .tcfConsentSettings .tcfCategoriesTabContent .consentSettingsRowContainer div {
# 	color: #fff;
# }
#   </style>
#   <script data-rocket-defer="" defer="" src="https://www.google.com/jsapi" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    google.load("search", "1");
#
#     // Call this function when the page has been loaded
#     function initialize() {
#         var searchControl = new google.search.SearchControl();
#         searchControl.addSearcher(new google.search.WebSearch());
#         searchControl.addSearcher(new google.search.NewsSearch());
#         searchControl.draw(document.getElementById("searchcontrol"));
#     }
#     google.setOnLoadCallback(initialize);
#   </script>
#   <script src="https://www.google.com/recaptcha/api.js">
#   </script>
#   <script>
#    (adsbygoogle = window.adsbygoogle || []).push({
#
#         google_ad_client: "ca-pub-7401091822721150",
#
#         enable_page_level_ads: true
#
#     });
#   </script>
#   <meta content="WP Rocket 3.17.3.1" data-wpr-features="wpr_defer_js wpr_oci wpr_desktop wpr_dns_prefetch" name="generator"/>
#  </head>
#  <body class="archive post-type-archive post-type-archive-review_airline js-legacy-header" data-rsssl="1">
#   <!--
# <div class="off-canvas-wrap" data-offcanvas>
#     <div class="inner-wrap">
# -->
#   <div id="container">
#    <header class="header header--legacy" role="banner">
#     <div id="inner-header">
#      <div class="top" id="mainMenu">
#       <div class="brand-logo">
#        <a href="https://www.airlinequality.com" rel="nofollow">
#         <img alt="SKYTRAX" onerror="this.src='https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/images/skytrax.png'" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/images/skytrax.svg"/>
#        </a>
#        <small>
#         Air Travel Ratings &amp; Reviews | Airline Rating and Reviews | Airport Rating and Reviews | Seat Reviews
#        </small>
#       </div>
#       <div class="menu-container">
#        <div class="gcs-input nav-search">
#         <div class="gcs-input">
#          <form action="/search " class="custom_search_form custom_search_form_header">
#           <input class="custom_search_form_input" dir="ltr" id="" name="search" placeholder="" spellcheck="false" title="search" type="text" value=""/>
#           <input class="custom_search_form_button desktop-search-button" title="search" type="submit" value="Search"/>
#           <button aria-label="Submit Search" class="button button-hero submit-search uppercase display text-heavy mobile-search-button">
#            <svg class="button-icon">
#             <use xlink:href="#search">
#             </use>
#            </svg>
#           </button>
#          </form>
#         </div>
#        </div>
#        <nav class="nav-user">
#         <ul class="sub-nav">
#          <li>
#           <a href="https://www.airlinequality.com/sign-in">
#            Log In
#           </a>
#          </li>
#          <li>
#           <a href="https://www.airlinequality.com/reviewer/reviewer-signup">
#            Join
#           </a>
#          </li>
#         </ul>
#        </nav>
#       </div>
#      </div>
#      <a class="menu-toggle" href="#mainMenu">
#       <span>
#        Menu
#       </span>
#      </a>
#      <div class="bottom">
#       <!-- Darren changed 2016-12-07 -->
#       <div class="nav-main-outer">
#        <div class="nav-main">
#         <nav class="top-bar" data-options="is_hover: true" data-topbar="">
#          <section class="top-bar-section nav__main">
#           <div class="top-bar top-bar-section">
#            <ul class="menu-class" id="menu-primary-site-navigation">
#             <li class="airline-reviews has-dropdown not-click">
#              <a href="#" target="">
#               Airline Reviews
#              </a>
#              <div class="dropdown">
#               <div class="nav-links">
#                <ul class="nav-links__list">
#                 <li class="airline-reviews navSectionTitle not-click">
#                  <a href="#" target="">
#                   Airline Reviews
#                  </a>
#                 </li>
#                 <li class="latest-airline-reviews not-click">
#                  <a href="https://www.airlinequality.com/review-pages/latest-airline-reviews/" target="">
#                   Latest Airline Reviews
#                  </a>
#                 </li>
#                 <li class="a-z-airline-reviews not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-airline-reviews/" target="">
#                   A-Z Airline Reviews
#                  </a>
#                 </li>
#                 <li class="airline-review-scores not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-airline-reviews/airline-review-ratings/" target="">
#                   Airline Review Scores
#                  </a>
#                 </li>
#                 <li class="a-z-airline-photos not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-airline-photos/" target="">
#                   A-Z Airline Photos
#                  </a>
#                 </li>
#                 <li class="airline-lounges navSectionTitle not-click">
#                  <a href="#" target="">
#                   Airline Lounges
#                  </a>
#                 </li>
#                 <li class="latest-lounge-reviews not-click">
#                  <a href="https://www.airlinequality.com/review-pages/latest-lounge-reviews/" target="">
#                   Latest Lounge Reviews
#                  </a>
#                 </li>
#                 <li class="a-z-airline-lounge-reviews not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-lounge-reviews/" target="">
#                   A-Z Airline Lounge Reviews
#                  </a>
#                 </li>
#                 <li class="lounge-photo-galleries not-click">
#                  <a href="https://www.airlinequality.com/info/lounge-photo-galleries/" target="">
#                   Lounge Photo Galleries
#                  </a>
#                 </li>
#                 <li class="airline-lounge-scores not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-lounge-reviews/airline-lounge-review-ratings/" target="">
#                   Airline Lounge Scores
#                  </a>
#                 </li>
#                 <li class="a-z-lounge-photos not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-lounge-photos/" target="">
#                   A-Z Lounge Photos
#                  </a>
#                 </li>
#                </ul>
#                <ul class="nav-links__list">
#                 <li class="seperator">
#                 </li>
#                 <li class="airline-seats navSectionTitle not-click">
#                  <a href="#" target="">
#                   Airline Seats
#                  </a>
#                 </li>
#                 <li class="latest-seat-reviews not-click">
#                  <a href="https://www.airlinequality.com/review-pages/latest-seat-reviews/" target="">
#                   Latest Seat Reviews
#                  </a>
#                 </li>
#                 <li class="a-z-airline-seat-reviews not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-seat-reviews/" target="">
#                   A-Z Airline Seat Reviews
#                  </a>
#                 </li>
#                 <li class="airline-seat-scores not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-seat-reviews/airline-seat-review-ratings/" target="">
#                   Airline Seat Scores
#                  </a>
#                 </li>
#                 <li class="a-z-seat-photos not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-seat-photos/" target="">
#                   A-Z Seat Photos
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </li>
#             <li class="airport-reviews has-dropdown not-click">
#              <a href="#" target="">
#               Airport Reviews
#              </a>
#              <div class="dropdown">
#               <div class="nav-links">
#                <ul class="nav-links__list">
#                 <li class="airport-reviews navSectionTitle not-click">
#                  <a href="#" target="">
#                   Airport Reviews
#                  </a>
#                 </li>
#                 <li class="latest-airport-reviews not-click">
#                  <a href="https://www.airlinequality.com/review-pages/latest-airport-reviews/" target="">
#                   Latest Airport Reviews
#                  </a>
#                 </li>
#                 <li class="a-z-airport-reviews not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-airport-reviews/" target="">
#                   A-Z Airport Reviews
#                  </a>
#                 </li>
#                 <li class="airport-review-scores not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-airport-reviews/airport-review-ratings/" target="">
#                   Airport Review Scores
#                  </a>
#                 </li>
#                 <li class="a-z-airport-photos not-click">
#                  <a href="https://www.airlinequality.com/review-pages/a-z-airport-photos/" target="">
#                   A-Z Airport Photos
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </li>
#             <li class="write-a-review not-click">
#              <a href="https://www.airlinequality.com/write-a-review/" target="">
#               Write A Review
#              </a>
#             </li>
#             <li class="airport-airline-rating has-dropdown not-click">
#              <a href="#" target="">
#               Airport &amp; Airline Rating
#              </a>
#              <div class="dropdown">
#               <div class="nav-links">
#                <ul class="nav-links__list">
#                 <li class="airline-rating navSectionTitle not-click">
#                  <a href="#" target="">
#                   Airline Rating
#                  </a>
#                 </li>
#                 <li class="a-z-airline-ratings not-click">
#                  <a href="https://skytraxratings.com/a-z-of-airline-ratings" target="_blank">
#                   A-Z Airline Ratings
#                  </a>
#                 </li>
#                 <li class="5-star-airlines not-click">
#                  <a href="https://skytraxratings.com/worlds-5-star-airlines" target="_blank">
#                   5-Star Airlines
#                  </a>
#                 </li>
#                </ul>
#                <ul class="nav-links__list">
#                 <li class="seperator">
#                 </li>
#                 <li class="airport-rating navSectionTitle not-click">
#                  <a href="#" target="">
#                   Airport Rating
#                  </a>
#                 </li>
#                 <li class="a-z-airport-ratings not-click">
#                  <a href="https://skytraxratings.com/a-z-of-airport-ratings" target="_blank">
#                   A-Z Airport Ratings
#                  </a>
#                 </li>
#                 <li class="5-star-airports not-click">
#                  <a href="https://skytraxratings.com/airports?stars=5" target="_blank">
#                   5-Star Airports
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </li>
#             <li class="skytrax-awards has-dropdown not-click">
#              <a href="#" target="">
#               Skytrax Awards
#              </a>
#              <div class="dropdown">
#               <div class="nav-links">
#                <ul class="nav-links__list">
#                 <li class="airline-awards navSectionTitle not-click">
#                  <a href="#" target="">
#                   Airline Awards
#                  </a>
#                 </li>
#                 <li class="worlds-best-airline not-click">
#                  <a href="https://www.worldairlineawards.com/worlds-top-10-airlines-2023/" target="_blank">
#                   World's Best Airline
#                  </a>
#                 </li>
#                 <li class="worlds-top-100-airlines not-click">
#                  <a href="https://www.worldairlineawards.com/worlds-top-100-airlines-2023/" target="_blank">
#                   World's Top 100 Airlines
#                  </a>
#                 </li>
#                 <li class="about-the-awards not-click">
#                  <a href="https://www.worldairlineawards.com/about-us/" target="_blank">
#                   About the Awards
#                  </a>
#                 </li>
#                </ul>
#                <ul class="nav-links__list">
#                 <li class="seperator">
#                 </li>
#                 <li class="airport-awards navSectionTitle not-click">
#                  <a href="#" target="">
#                   Airport Awards
#                  </a>
#                 </li>
#                 <li class="worlds-best-airport not-click">
#                  <a href="https://www.worldairportawards.com/the-worlds-top-10-airports-of-2023/" target="_blank">
#                   World's Best Airport
#                  </a>
#                 </li>
#                 <li class="worlds-top-100-airports not-click">
#                  <a href="https://www.worldairportawards.com/worlds-top-100-airports-2023/" target="_blank">
#                   World's Top 100 Airports
#                  </a>
#                 </li>
#                 <li class="about-the-awards not-click">
#                  <a href="https://www.worldairportawards.com/about-us/" target="_blank">
#                   About the Awards
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </li>
#             <li class="information has-dropdown not-click">
#              <a href="#" target="">
#               Information
#              </a>
#              <div class="dropdown">
#               <div class="nav-links">
#                <ul class="nav-links__list">
#                 <li class="information navSectionTitle not-click">
#                  <a href="#" target="">
#                   Information
#                  </a>
#                 </li>
#                 <li class="about-us not-click">
#                  <a href="https://www.airlinequality.com/about-us/" target="">
#                   About Us
#                  </a>
#                 </li>
#                 <li class="site-map not-click">
#                  <a href="https://www.airlinequality.com/site-map/" target="">
#                   Site Map
#                  </a>
#                 </li>
#                </ul>
#                <ul class="nav-links__list">
#                 <li class="seperator">
#                 </li>
#                 <li class="help-support navSectionTitle not-click">
#                  <a href="#" target="">
#                   Help &amp; Support
#                  </a>
#                 </li>
#                 <li class="contact-us not-click">
#                  <a href="https://www.airlinequality.com/contact-us/" target="">
#                   Contact Us
#                  </a>
#                 </li>
#                 <li class="faqs not-click">
#                  <a href="https://www.airlinequality.com/info/support/" target="">
#                   FAQs
#                  </a>
#                 </li>
#                 <li class="register-as-a-member not-click">
#                  <a href="https://www.airlinequality.com/info/reviewer-signup/" target="">
#                   Register as a Member
#                  </a>
#                 </li>
#                 <li class="editorial-policy not-click">
#                  <a href="https://www.airlinequality.com/info/editorial-policy/" target="">
#                   Editorial Policy
#                  </a>
#                 </li>
#                 <li class="respond-to-reviews not-click">
#                  <a href="https://www.airlinequality.com/info/skychat/" target="">
#                   Respond to Reviews
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </li>
#            </ul>
#           </div>
#          </section>
#         </nav>
#        </div>
#       </div>
#       <div class="ds-search-outer">
#        <div class="ds-search">
#         <div class="gcs-input nav-search">
#          <div class="gcs-input">
#           <form action="/search " class="custom_search_form custom_search_form_header">
#            <input class="custom_search_form_input" dir="ltr" id="" name="search" placeholder="" spellcheck="false" title="search" type="text" value=""/>
#            <input class="custom_search_form_button desktop-search-button" title="search" type="submit" value="Search"/>
#            <button aria-label="Submit Search" class="button button-hero submit-search uppercase display text-heavy mobile-search-button">
#             <svg class="button-icon">
#              <use xlink:href="#search">
#              </use>
#             </svg>
#            </button>
#           </form>
#          </div>
#         </div>
#        </div>
#       </div>
#       <!-- Darren changed 2016-12-07 -->
#      </div>
#     </div>
#     <div class="dummyheader">
#      <div class="top">
#       <div class="brand-logo">
#        <a href="https://www.airlinequality.com" rel="nofollow">
#         <img alt="SKYTRAX" onerror="this.src='https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/images/skytrax.png'" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/images/skytrax.svg"/>
#        </a>
#       </div>
#      </div>
#      <a class="menu-toggle" href="#mainMenu">
#       <span>
#        Menu
#       </span>
#      </a>
#     </div>
#    </header>
#    <div id="content" itemscope="" itemtype="http://schema.org/Airline">
#     <div class="clearfix" id="inner-content">
#      <div id="main" role="main">
#       <section class="layout-section layout-1">
#        <div class="col-content">
#         <section class="comp_review-header">
#          <div class="review-ad">
#           <div class="aq-ad">
#            <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#            </script>
#            <ins class="adsbygoogle" data-ad-client="ca-pub-7401091822721150" data-ad-format="auto" data-ad-slot="8663246558" style="display:block;">
#            </ins>
#            <script>
#             (adsbygoogle = window.adsbygoogle || []).push({});
#            </script>
#           </div>
#          </div>
#          <div class="review-info">
#           <div class="review-heading">
#            <div class="info">
#             <div class="logo">
#              <img alt="" class="attachment-rating_long size-rating_long" decoding="async" height="24" sizes="(max-width: 150px) 100vw, 150px" src="https://www.airlinequality.com/wp-content/uploads/2015/01/British_Airways_logo-150x24.png" srcset="https://www.airlinequality.com/wp-content/uploads/2015/01/British_Airways_logo-150x24.png 150w, https://www.airlinequality.com/wp-content/uploads/2015/01/British_Airways_logo-300x47.png 300w, https://www.airlinequality.com/wp-content/uploads/2015/01/British_Airways_logo-1024x161.png 1024w, https://www.airlinequality.com/wp-content/uploads/2015/01/British_Airways_logo-120x19.png 120w, https://www.airlinequality.com/wp-content/uploads/2015/01/British_Airways_logo-600x94.png 600w, https://www.airlinequality.com/wp-content/uploads/2015/01/British_Airways_logo.png 1471w" width="150"/>
#             </div>
#             <h1 itemprop="name">
#              British Airways
#             </h1>
#             <h2>
#              Customer Reviews
#             </h2>
#            </div>
#            <div class="rating">
#             <img alt="4 star Skytrax Rating" class="skytrax-rating" srcset="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/images/skytrax-rating-airline-4.png 1x, https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/images/skytrax-rating-airline-4x2.png 2x"/>
#            </div>
#           </div>
#           <div class="customer-rating">
#            <div class="ratings">
#             <table class="review-ratings">
#              <tbody>
#               <tr>
#                <td class="review-rating-header food-beverages">
#                 Food &amp; Beverages
#                </td>
#                <td class="review-rating-stars stars">
#                 <span class="star fill">
#                  1
#                 </span>
#                 <span class="star fill">
#                  2
#                 </span>
#                 <span class="star fill">
#                  3
#                 </span>
#                 <span class="star">
#                  4
#                 </span>
#                 <span class="star">
#                  5
#                 </span>
#                </td>
#               </tr>
#               <tr>
#                <td class="review-rating-header inflight-entertainment">
#                 Inflight Entertainment
#                </td>
#                <td class="review-rating-stars stars">
#                 <span class="star fill">
#                  1
#                 </span>
#                 <span class="star fill">
#                  2
#                 </span>
#                 <span class="star fill">
#                  3
#                 </span>
#                 <span class="star">
#                  4
#                 </span>
#                 <span class="star">
#                  5
#                 </span>
#                </td>
#               </tr>
#               <tr>
#                <td class="review-rating-header seat-comfort">
#                 Seat Comfort
#                </td>
#                <td class="review-rating-stars stars">
#                 <span class="star fill">
#                  1
#                 </span>
#                 <span class="star fill">
#                  2
#                 </span>
#                 <span class="star fill">
#                  3
#                 </span>
#                 <span class="star">
#                  4
#                 </span>
#                 <span class="star">
#                  5
#                 </span>
#                </td>
#               </tr>
#               <tr>
#                <td class="review-rating-header staff-service">
#                 Staff Service
#                </td>
#                <td class="review-rating-stars stars">
#                 <span class="star fill">
#                  1
#                 </span>
#                 <span class="star fill">
#                  2
#                 </span>
#                 <span class="star fill">
#                  3
#                 </span>
#                 <span class="star">
#                  4
#                 </span>
#                 <span class="star">
#                  5
#                 </span>
#                </td>
#               </tr>
#               <tr>
#                <td class="review-rating-header value-for-money">
#                 Value for Money
#                </td>
#                <td class="review-rating-stars stars">
#                 <span class="star fill">
#                  1
#                 </span>
#                 <span class="star fill">
#                  2
#                 </span>
#                 <span class="star fill">
#                  3
#                 </span>
#                 <span class="star">
#                  4
#                 </span>
#                 <span class="star">
#                  5
#                 </span>
#                </td>
#               </tr>
#              </tbody>
#             </table>
#            </div>
#            <div class="rating-totals" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating">
#             <div class="review-count">
#              Customer rating from
#              <span itemprop="reviewCount">
#               3910
#              </span>
#              reviews
#             </div>
#             <div class="customer-rating-total">
#              <div class="rating-10 rating-large">
#               <span itemprop="ratingValue">
#                5
#               </span>
#               /
#               <span itemprop="bestRating">
#                10
#               </span>
#              </div>
#             </div>
#             <div class="skytrax-rating-mob">
#              <img alt="4 star Skytrax Rating" class="skytrax-rating" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/images/skytrax-rating-airline-4.png"/>
#             </div>
#            </div>
#           </div>
#          </div>
#         </section>
#         <div class="aq-ad">
#          <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#          </script>
#          <ins class="adsbygoogle" data-ad-client="ca-pub-7401091822721150" data-ad-format="auto" data-ad-slot="9526159642" style="display:block;">
#          </ins>
#          <script>
#           (adsbygoogle = window.adsbygoogle || []).push({});
#          </script>
#         </div>
#        </div>
#       </section>
#       <section class="layout-section layout-1 closer-bottom full-width-bg">
#        <div class="col-content">
#         <section class="comp comp__review-tabs">
#          <nav class="write-a-review">
#           <a href="/write-a-review?type=airline&amp;e=british-airways">
#            Write
#                         a Review
#           </a>
#          </nav>
#          <ul class="tabs">
#           <li class="tab-title airline active">
#            <a href="/airline-reviews/british-airways">
#             Airline
#            </a>
#           </li>
#           <li class="tab-title seat">
#            <a href="/seat-reviews/british-airways">
#             Seat
#            </a>
#           </li>
#           <li class="tab-title lounge">
#            <a href="/lounge-reviews/british-airways">
#             Lounge
#            </a>
#           </li>
#          </ul>
#         </section>
#        </div>
#       </section>
#       <section class="layout-section layout-2 closer-top">
#        <div class="col-content">
#         <article class="comp comp_reviews-airline querylist position-content">
#          <div class="pagination-controls">
#           <div class="pagination-filter">
#            <form method="get">
#             <span class="pagination-label">
#              Filter Reviews by :
#             </span>
#             <input name="pagesize" type="hidden" value="10"/>
#             <select class="page-filter-selector" data-onchange-submit="" name="filterby">
#              <option selected="" value="">
#               Latest reviews
#              </option>
#              <option value="cabin:first">
#               First Class
#              </option>
#              <option value="cabin:business">
#               Business Class
#              </option>
#              <option value="cabin:p_economy">
#               Premium Economy
#              </option>
#              <option value="cabin:economy">
#               Economy Class
#              </option>
#             </select>
#            </form>
#           </div>
#           <div class="pagination-size">
#            <form method="get">
#             <span class="pagination-label">
#              Show
#             </span>
#             <input name="sortby" type="hidden" value="post_date:Desc"/>
#             <ul class="page-size-selector">
#              <li>
#               <input checked="" data-onchange-submit="" id="10" name="pagesize" type="radio" value="10"/>
#               <label for="10">
#                10
#               </label>
#              </li>
#              <li>
#               <input data-onchange-submit="" id="20" name="pagesize" type="radio" value="20"/>
#               <label for="20">
#                20
#               </label>
#              </li>
#              <li>
#               <input data-onchange-submit="" id="50" name="pagesize" type="radio" value="50"/>
#               <label for="50">
#                50
#               </label>
#              </li>
#              <li>
#               <input data-onchange-submit="" id="100" name="pagesize" type="radio" value="100"/>
#               <label for="100">
#                100
#               </label>
#              </li>
#             </ul>
#            </form>
#           </div>
#          </div>
#          <article class="comp comp_media-review-rated list-item media position-content review-917550" itemprop="review" itemscope="" itemtype="http://schema.org/Review">
#           <meta content="2025-01-19" itemprop="datePublished"/>
#           <div class="rating-10" itemprop="reviewRating" itemscope="" itemtype="http://schema.org/Rating">
#            <span itemprop="ratingValue">
#             7
#            </span>
#            /
#            <span itemprop="bestRating">
#             10
#            </span>
#           </div>
#           <div class="body" id="anchor917550">
#            <h2 class="text_header">
#             "relatively comfortable elderly plane"
#            </h2>
#            <h3 class="text_sub_header userStatusWrapper">
#             <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
#              <span itemprop="name">
#               Simon Channon
#              </span>
#             </span>
#             (United Kingdom)
#             <time datetime="2025-01-19" itemprop="datePublished">
#              19th January 2025
#             </time>
#            </h3>
#            <div class="tc_mobile">
#             <div class="text_content" itemprop="reviewBody">
#              <strong>
#               <a href="https://www.airlinequality.com/verified-reviews/">
#                <em>
#                 Not Verified
#                </em>
#               </a>
#              </strong>
#              |  An hour's delay due to late arrival of the incoming aircraft. The captain was a particularly able communicator who kept us in touch with the situation. We got freebie upgrades to emergency exit seats from a friendly member of the crew. In the end we were only 30 minutes behind schedule in a relatively comfortable elderly plane. Pretty stress free.
#             </div>
#             <div class="review-stats">
#              <table class="review-ratings">
#               <tbody>
#                <tr>
#                 <td class="review-rating-header aircraft">
#                  Aircraft
#                 </td>
#                 <td class="review-value">
#                  A319
#                 </td>
#                </tr>
#                <tr>
#                 <td class="review-rating-header type_of_traveller">
#                  Type Of Traveller
#                 </td>
#                 <td class="review-value">
#                  Family Leisure
#                 </td>
#                </tr>
#                <tr>
#                 <td class="review-rating-header cabin_flown">
#                  Seat Type
#                 </td>
#                 <td class="review-value">
#                  Economy Class
#                 </td>
#                </tr>
#                <tr>
#                 <td class="review-rating-header route">
#                  Route
#                 </td>
#                 <td class="review-value">
#                  London to Lisbon
#                 </td>
#                </tr>
#                <tr>
#                 <td class="review-rating-header date_flown">
#                  Date Flown
#                 </td>
#                 <td class="review-value">
#                  January 2025
#                 </td>
#                </tr>
#                <tr>
#                 <td class="review-rating-header seat_comfort">
#                  Seat Comfort
#                 </td>
#                 <td class="review-rating-stars stars">
#                  <span class="star fill">
#                   1
#                  </span>
#                  <span class="star fill">
#                   2
#                  </span>
#                  <span class="star fill">
#                   3
#                  </span>
#                  <span class="star">
#                   4
#                  </span>
#                  <span class="star">
#                   5
#                  </span>
#                 </td>
#                </tr>
#                <tr>
#                 <td class="review-rating-header cabin_staff_service">
#                  Cabin Staff Service
#                 </td>
#                 <td class="review-rating-stars stars">
#                  <span class="star fill">
#                   1
#                  </span>
#                  <span class="star fill">
#                   2
#                  </span>
#                  <span class="star fill">
#                   3
#                  </span>
#                  <span class="star fill">
#                   4
#                  </span>
#                  <span class="star">
#                   5
#                  </span>
#                 </td>
#                </tr>
#                <tr>
#                 <td class="review-rating-header food_and_beverages">
#                  Food &amp; Beverages
#                 </td>
#                 <td class="review-rating-stars stars">
#                  <span class="star fill">
#                   1
#                  </span>
#                  <span class="star fill">
#                   2
#                  </span>
#                  <span class="star">
#                   3
#                  </span>
#                  <span class="star">
#                   4
#                  </span>
#                  <span class="star">
#                   5
#                  </span>
#                 </td>
#                </tr>
#                <tr>
#                 <td class="review-rating-header ground_service">
#                  Ground Service
#                 </td>
#                 <td class="review-rating-stars stars">
#                  <span class="star fill">
#                   1
#                  </span>
#                  <span class="star fill">
#                   2
#                  </span>
#                  <span class="star fill">
#                   3
#                  </span>
#                  <span class="star fill">
#                   4
#                  </span>
#                  <span class="star">
#                   5
#                  </span>
#                 </td>
#                </tr>
#                <tr>
#                 <td class="review-rating-header value_for_money">
#                  Value For Money
#                 </td>
#                 <td class="review-rating-stars stars">
# ...
#              Seat width : 17.5 ins
#             </span>
#             <br/>
#             <span>
#              <img alt="No WiFi" class="alignnone size-full wp-image-386579" height="16" src="https://www.airlinequality.com/wp-content/uploads/2015/05/No_WiFi.png" width="48"/>
#              Onboard WiFi
#             </span>
#             <br/>
#             <span>
#              <img alt="power_icon" class="alignnone size-full wp-image-386553" height="16" src="https://www.airlinequality.com/wp-content/uploads/2015/05/power_icon.png" width="48"/>
#              USB power
#             </span>
#             <br/>
#             <span>
#              <img alt="AVOD" class="alignnone size-full wp-image-386555" height="16" src="https://www.airlinequality.com/wp-content/uploads/2015/05/avod_icon.png" width="48"/>
#              Audio / video on demand
#             </span>
#             <br/>
#             <span>
#              <img alt="Dining" class="alignnone size-full wp-image-386556" height="16" src="https://www.airlinequality.com/wp-content/uploads/2015/05/meals_icontick.png" width="48"/>
#              Complimentary meal
#             </span>
#             <br/>
#             <span>
#              <img alt="Wines" class="alignnone size-full wp-image-386557" height="16" src="https://www.airlinequality.com/wp-content/uploads/2015/05/wines_icon.png" width="48"/>
#              Complimentary beverages &amp; wines
#             </span>
#             <br/>
#             <span>
#              <img alt="Sleeping" class="alignnone size-full wp-image-386560" height="16" src="https://www.airlinequality.com/wp-content/uploads/2015/05/sleeping_icon.png" width="48"/>
#              Pillow / blanket
#             </span>
#             <br/>
#             <span>
#             </span>
#             <br/>
#             <span>
#              <strong>
#               SHORT HAUL
#              </strong>
#             </span>
#             <br/>
#             <span>
#              <img alt="Seat pitch" class="alignnone size-full wp-image-386568" height="16" src="https://www.airlinequality.com/wp-content/uploads/2015/05/seating_icon.png" width="48"/>
#              Seat pitch : 29-30 ins
#             </span>
#             <br/>
#             <span>
#              <img alt="Seat width" class="alignnone size-full wp-image-386567" height="16" src="https://www.airlinequality.com/wp-content/uploads/2015/05/seatwidth_icon.png" width="48"/>
#              Seat width : 17 ins
#             </span>
#             <br/>
#             <span>
#              <img alt="" class="alignnone size-full wp-image-483985" height="16" src="https://www.airlinequality.com/wp-content/uploads/2015/05/USB_NO.png" width="48"/>
#              In-seat &amp;/or USB power
#             </span>
#             <br/>
#             <span>
#              <img alt="No WiFi" class="alignnone size-full wp-image-386579" height="16" src="https://www.airlinequality.com/wp-content/uploads/2015/05/No_WiFi.png" width="48"/>
#              Onboard WiFi
#             </span>
#             <br/>
#             <span>
#              <img alt="" class="alignnone size-full wp-image-483984" height="16" src="https://www.airlinequality.com/wp-content/uploads/2015/05/IFE_nothing.png" width="48"/>
#              Inflight entertainment
#             </span>
#             <br/>
#             <span>
#              <img alt="" class="alignnone size-full wp-image-483965" height="16" src="https://www.airlinequality.com/wp-content/uploads/2017/05/OD_Dine_NO.png" width="48"/>
#              Complimentary meal / beverages
#             </span>
#            </p>
#            <div class="lightbox">
#             <div class="widgetImg solo">
#              <a data-imagelightbox="ECONOMY CLASS" href="https://www.airlinequality.com/wp-content/uploads/2015/05/BA_Y_Class_seat-800x471.jpg">
#               <img src="https://www.airlinequality.com/wp-content/uploads/2015/05/BA_Y_Class_seat-297x187.jpg"/>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </section>
#      </div>
#      <!-- end #main -->
#     </div>
#     <!-- end #inner-content -->
#    </div>
#    <!-- end #content -->
#    <div id="content">
#     <div class="clearfix" id="inner-content">
#      <div id="main" role="main">
#       <section class="layout-section layout-1 border-top">
#        <div class="col-content">
#         <div class="aq-ad">
#          <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#          </script>
#          <ins class="adsbygoogle" data-ad-client="ca-pub-7401091822721150" data-ad-format="auto" data-ad-slot="1761601644" style="display:block;">
#          </ins>
#          <script>
#           (adsbygoogle = window.adsbygoogle || []).push({});
#          </script>
#         </div>
#        </div>
#       </section>
#      </div>
#     </div>
#    </div>
#    <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#    </script>
#    <ins class="adsbygoogle" data-ad-channel="8143418842" data-ad-client="ca-pub-7401091822721150" data-reactive-ad-format="1" style="display:none">
#    </ins>
#    <script>
#     (adsbygoogle = window.adsbygoogle || []).push({});
#    </script>
#    <footer class="footer clearfix" role="contentinfo">
#     <div id="inner-footer">
#      <div class="footer-nav quick-links">
#       <h2>
#        Quick Links
#       </h2>
#       <ul class="footer-main-nav side-nav" id="menu-quick-links">
#        <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-155421" id="menu-item-155421">
#         <a href="https://www.airlinequality.com/info/cookies/">
#          Cookies Policy
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-884780" id="menu-item-884780">
#         <a href="https://www.airlinequality.com/info/privacy-policy/">
#          Privacy Policy
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-88544" id="menu-item-88544">
#         <a href="https://www.airlinequality.com/info/legal-use/">
#          Terms &amp; Conditions
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-88548" id="menu-item-88548">
#         <a href="https://www.airlinequality.com/info/editorial-policy/">
#          Editorial Policy
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="footer-nav about-links">
#       <h2>
#        About
#       </h2>
#       <ul class="footer-sub-nav side-nav" id="menu-about-links">
#        <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-88793" id="menu-item-88793">
#         <a href="https://www.airlinequality.com/contact-us/">
#          Contact &amp; Feedback
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-154908" id="menu-item-154908">
#         <a href="https://www.airlinequality.com/info/support/">
#          Help &amp; Support
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-88796" id="menu-item-88796">
#         <a href="https://www.airlinequality.com/about-us/">
#          About Us
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-667262" id="menu-item-667262">
#         <a href="https://www.airlinequality.com/site-map/">
#          Site Map
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="description">
#       <p>
#        The comprehensive Airline and Airport customer review site for airlines and airports across the world. Read traveller reviews and opinions for Airlines and Airports worldwide, airline lounges and airline Seats. View airline, airport, seat, and lounge photos.
#       </p>
#       <p>
#        © 1999-2025 Copyright SKYTRAX
#       </p>
#       <ul class="social">
#        <li class="facebook">
#         <a href="https://www.facebook.com/pages/Skytrax/110801075638605" target="_blank">
#          Follow us on facebook
#         </a>
#        </li>
#        <li class="twitter">
#         <a href="https://twitter.com/airlinequality" target="_blank">
#          Follow us on twitter
#         </a>
#        </li>
#        <li class="youtube">
#         <a href="https://www.youtube.com/channel/UCxnW-L6M9GZPeShvIq5x-Ug" target="_blank">
#          Follow us on YouTube
#         </a>
#        </li>
#        <li class="instagram">
#         <a href="https://instagram.com/skytrax_uk/" target="_blank">
#          Follow us on Instagram
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <!--    <div class="credit">-->
#     <!-- <p><a href="http://gendall.co.uk/">Developed by Gendall</a></p>-->
#     <!--    </div>-->
#     <!-- end #inner-footer -->
#    </footer>
#    <!-- end .footer -->
#   </div>
#   <!-- end #container -->
#   <!-- </div> -->
#   <!-- end .inner-wrap -->
#   <!-- </div> -->
#   <!-- end .off-canvas-wrap -->
#   <!-- all js scripts are loaded in library/joints.php -->
#   <script id="google_cse_v2-js-extra" type="text/javascript">
#    /* <![CDATA[ */
# var scriptParams = {"google_search_engine_id":"017679995690221766716:2jeansnuuqa"};
# /* ]]> */
#   </script>
#   <script data-rocket-defer="" defer="" id="google_cse_v2-js" src="https://www.airlinequality.com/wp-content/plugins/wp-google-search/assets/js/google_cse_v2.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="foundation-js-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/foundation/foundation.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="foundation-js-offcanvas-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/foundation/foundation.offcanvas.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="foundation-js-tab-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/foundation/foundation.tab.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="foundation-js-dropdown-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/foundation/foundation.dropdown.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="foundation-js-abide-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/foundation/foundation.abide.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="foundation-js-clearing-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/foundation/foundation.clearing.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="foundation-js-accordion-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/foundation/foundation.accordion.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="foundation-js-tooltip-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/foundation/foundation.tooltip.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="jquery-ui-core-js" src="https://www.airlinequality.com/wp-includes/js/jquery/ui/core.min.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="jquery-ui-mouse-js" src="https://www.airlinequality.com/wp-includes/js/jquery/ui/mouse.min.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="jquery-ui-slider-js" src="https://www.airlinequality.com/wp-includes/js/jquery/ui/slider.min.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="touchpunch-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/vendor/jquery.ui.touch-punch.min.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="lightbox-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/vendor/lightbox.min.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="textCounter-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/vendor/textcounter.min.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="slick-js" src="//cdn.jsdelivr.net/npm/slick-carousel@1.8.1/slick/slick.min.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="jquery-ui-menu-js" src="https://www.airlinequality.com/wp-includes/js/jquery/ui/menu.min.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="wp-dom-ready-js" src="https://www.airlinequality.com/wp-includes/js/dist/dom-ready.min.js" type="text/javascript">
#   </script>
#   <script id="wp-hooks-js" src="https://www.airlinequality.com/wp-includes/js/dist/hooks.min.js" type="text/javascript">
#   </script>
#   <script id="wp-i18n-js" src="https://www.airlinequality.com/wp-includes/js/dist/i18n.min.js" type="text/javascript">
#   </script>
#   <script id="wp-i18n-js-after" type="text/javascript">
#    /* <![CDATA[ */
# wp.i18n.setLocaleData( { 'text direction\u0004ltr': [ 'ltr' ] } );
# /* ]]> */
#   </script>
#   <script id="wp-a11y-js-translations" type="text/javascript">
#    /* <![CDATA[ */
# ( function( domain, translations ) {
# 	var localeData = translations.locale_data[ domain ] || translations.locale_data.messages;
# 	localeData[""].domain = domain;
# 	wp.i18n.setLocaleData( localeData, domain );
# } )( "default", {"translation-revision-date":"2024-11-14 20:13:08+0000","generator":"GlotPress\/4.0.1","domain":"messages","locale_data":{"messages":{"":{"domain":"messages","plural-forms":"nplurals=2; plural=n != 1;","lang":"en_GB"},"Notifications":["Notifications"]}},"comment":{"reference":"wp-includes\/js\/dist\/a11y.js"}} );
# /* ]]> */
#   </script>
#   <script data-rocket-defer="" defer="" id="wp-a11y-js" src="https://www.airlinequality.com/wp-includes/js/dist/a11y.min.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="jquery-ui-autocomplete-js" src="https://www.airlinequality.com/wp-includes/js/jquery/ui/autocomplete.min.js" type="text/javascript">
#   </script>
#   <script data-rocket-defer="" defer="" id="joints-js-js" src="https://www.airlinequality.com/wp-content/themes/airlinequality2014new/library/js/scripts.js" type="text/javascript">
#   </script>
#   <!--[if lt IE 9]>
# <script src="library/js/rem.js" type="text/javascript"></script>
# <![endif]-->
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-7107328-1', 'auto');
#   ga('send', 'pageview');
#   </script>
#   <script>
#    (function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'9050d522a86beb40',t:'MTczNzM5NDY0OC4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();
#   </script>
#  </body>
# </html>
# <!-- end page -->
# <!-- This website is like a Rocket, isn't it? Performance optimized by WP Rocket. Learn more: https://wp-rocket.me -->

# %% [markdown]
# ## Scraping all pages

# %%
import time
import requests
import re
from bs4 import BeautifulSoup

def ref_rev(base_url,AR):
    dic={'AI':100,'BA':100,'ET':100,'EM':100,'QA':100}

    reviews = []
    dates = []
    country=[]

    for i in range(1, dic.get(AR)):
        url = f"{base_url}/page/{i}"
        response = requests.get(url)
        data = response.text
        soup = BeautifulSoup(data, 'html5lib')

        h2_elements = soup.body.find_all('h2', class_="text_header")
        h3_elements = soup.find_all('time')
        h3_country = soup.find_all(class_="text_sub_header userStatusWrapper")
        for tag in h3_country:
            text = tag.get_text()
            country_match = re.search(r'\((.*?)\)', text)
            if country_match:
                country.append(country_match.group(1))



        h2_texts = [h2.text for h2 in h2_elements[0:10]]
        h3_texts = [h3.text for h3 in h3_elements[0:10]]

        reviews.extend(h2_texts)
        dates.extend(h3_texts)


    return dates,reviews,country

# %%
dates0,reviews0,country0= ref_rev("https://www.airlinequality.com/airline-reviews/british-airways",'BA')
dates1,reviews1,country1=ref_rev("https://www.airlinequality.com/airline-reviews/air-india",'AI')
dates2,reviews2,country2=ref_rev("https://www.airlinequality.com/airline-reviews/emirates",'EM')
dates3,reviews3,country3=ref_rev("https://www.airlinequality.com/airline-reviews/etihad-airways",'ET')
dates4,reviews4,country4=ref_rev("https://www.airlinequality.com/airline-reviews/qatar-airways",'QA')

# %%
country4
# Out:
# ['Iceland',
#  'Iceland',
#  'France',
#  'Australia',
#  'Germany',
#  'Germany',
#  'France',
#  'Kuwait',
#  'Finland',
#  'China',
#  'Greece',
#  'United Kingdom',
#  'Sweden',
#  'Sweden',
#  'Sweden',
#  'Spain',
#  'Malaysia',
#  'United States',
#  'Sweden',
#  'Australia',
#  'Australia',
#  'Russian Federation',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'Netherlands',
#  'United Arab Emirates',
#  'Qatar',
#  'Spain',
#  'United States',
#  'United States',
#  'United States',
#  'India',
#  'Australia',
#  'Spain',
#  'Nepal',
#  'Cayman Islands',
#  'United Kingdom',
#  'United Kingdom',
#  'Australia',
#  'Norway',
#  'Pakistan',
#  'Qatar',
#  'Australia',
#  'United Kingdom',
#  'Qatar',
#  'Australia',
#  'United Kingdom',
#  'United Arab Emirates',
#  'Singapore',
#  'United Kingdom',
#  'United Kingdom',
#  'Netherlands',
#  'United Kingdom',
#  'France',
#  'United Kingdom',
#  'United Kingdom',
#  'Finland',
#  'Malaysia',
#  'Australia',
#  'Thailand',
#  'Thailand',
#  'New Zealand',
#  'United States',
#  'Romania',
#  'United Kingdom',
#  'Bahrain',
#  'Saudi Arabia',
#  'Australia',
#  'United Kingdom',
#  'United States',
#  'Australia',
#  'Malaysia',
#  'United Kingdom',
#  'Malaysia',
#  'United Kingdom',
#  'Germany',
#  'Germany',
#  'United Arab Emirates',
#  'Iceland',
#  'Qatar',
#  'Australia',
#  'Hong Kong',
#  'United Kingdom',
#  'United Arab Emirates',
#  'Qatar',
#  'United Kingdom',
#  'United Kingdom',
#  'United States',
#  'Australia',
#  'Netherlands',
#  'United Kingdom',
#  'India',
#  'United Arab Emirates',
#  'South Africa',
#  'Spain',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'Armenia',
#  'Iceland',
#  'Iceland',
#  'Australia',
#  'Singapore',
#  'Netherlands',
#  'United States',
#  'United States',
#  'Australia',
#  'United Kingdom',
#  'Poland',
#  'Kenya',
#  'Qatar',
#  'Belgium',
#  'United Kingdom',
#  'Norway',
#  'Germany',
#  'Singapore',
#  'Portugal',
#  'Austria',
#  'Singapore',
#  'Qatar',
#  'Germany',
#  'Germany',
#  'Qatar',
#  'Canada',
#  'Iraq',
#  'Singapore',
#  'Australia',
#  'Netherlands',
#  'United Kingdom',
#  'United Kingdom',
#  'Poland',
#  'Cambodia',
#  'Cayman Islands',
#  'United States',
#  'United Kingdom',
#  'Romania',
#  'Qatar',
#  'Lebanon',
#  'United Kingdom',
#  'Thailand',
#  'Ireland',
#  'United Kingdom',
#  'United Arab Emirates',
#  'United Arab Emirates',
#  'South Africa',
#  'Vietnam',
#  'Canada',
#  'Canada',
#  'France',
#  'United States',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Qatar',
#  'Cyprus',
#  'Qatar',
#  'Australia',
#  'Taiwan',
#  'Kuwait',
#  'Germany',
#  'United Kingdom',
#  'Kuwait',
#  'Netherlands',
#  'Germany',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'Iceland',
#  'Finland',
#  'United Kingdom',
#  'United Kingdom',
#  'United States',
#  'Australia',
#  'United Kingdom',
#  'Germany',
#  'France',
#  'Germany',
#  'United Kingdom',
#  'Germany',
#  'Australia',
#  'United Kingdom',
#  'Germany',
#  'Netherlands',
#  'Bulgaria',
#  'Sweden',
#  'Germany',
#  'United Kingdom',
#  'Canada',
#  'Australia',
#  'Qatar',
#  'United Kingdom',
#  'United Kingdom',
#  'United States',
#  'Germany',
#  'Germany',
#  'United States',
#  'United States',
#  'Qatar',
#  'Australia',
#  'United Kingdom',
#  'United States',
#  'Australia',
#  'Singapore',
#  'Australia',
#  'Lebanon',
#  'United Kingdom',
#  'United Kingdom',
#  'Iceland',
#  'Iceland',
#  'United Kingdom',
#  'United States',
#  'Australia',
#  'Greece',
#  'Denmark',
#  'Germany',
#  'Switzerland',
#  'Germany',
#  'Belgium',
#  'Australia',
#  'United Kingdom',
#  'Kuwait',
#  'Bahrain',
#  'United Arab Emirates',
#  'United Kingdom',
#  'Italy',
#  'Australia',
#  'South Africa',
#  'Switzerland',
#  'Netherlands',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'Belgium',
#  'Australia',
#  'Sweden',
#  'Sweden',
#  'Sweden',
#  'United States',
#  'United Kingdom',
#  'Denmark',
#  'France',
#  'United Kingdom',
#  'Denmark',
#  'Germany',
#  'Nepal',
#  'United States',
#  'Germany',
#  'China',
#  'France',
#  'Kuwait',
#  'United Kingdom',
#  'United Kingdom',
#  'Australia',
#  'United Arab Emirates',
#  'United Arab Emirates',
#  'United Kingdom',
#  'South Africa',
#  'Thailand',
#  'Australia',
#  'United States',
#  'France',
#  'United States',
#  'Australia',
#  'Oman',
#  'Czech Republic',
#  'Singapore',
#  'Bahrain',
#  'Austria',
#  'Qatar',
#  'Australia',
#  'Germany',
#  'United Kingdom',
#  'Uganda',
#  'Germany',
#  'Germany',
#  'New Zealand',
#  'United States',
#  'South Africa',
#  'Australia',
#  'Australia',
#  'United States',
#  'Lebanon',
#  'Germany',
#  'Australia',
#  'United Kingdom',
#  'Thailand',
#  'Poland',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'Australia',
#  'Pakistan',
#  'Sri Lanka',
#  'New Zealand',
#  'United Kingdom',
#  'Qatar',
#  'Iran',
#  'India',
#  'India',
#  'United States',
#  'France',
#  'Germany',
#  'Germany',
#  'United States',
#  'Italy',
#  'South Africa',
#  'Indonesia',
#  'Australia',
#  'Vietnam',
#  'Netherlands',
#  'Belgium',
#  'Australia',
#  'Kenya',
#  'Romania',
#  'Poland',
#  'Belgium',
#  'United Kingdom',
#  'Germany',
#  'Ireland',
#  'Nigeria',
#  'United Kingdom',
#  'Philippines',
#  'United States',
#  'South Africa',
#  'South Africa',
#  'United Kingdom',
#  'India',
#  'United States',
#  'New Zealand',
#  'United Arab Emirates',
#  'Hong Kong',
#  'United States',
#  'Germany',
#  'United States',
#  'Romania',
#  'France',
#  'Vietnam',
#  'Netherlands',
#  'Qatar',
#  'United States',
#  'Bulgaria',
#  'New Zealand',
#  'Germany',
#  'Australia',
#  'Philippines',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'Philippines',
#  'Thailand',
#  'Thailand',
#  'United Kingdom',
#  'Australia',
#  'Germany',
#  'Australia',
#  'Germany',
#  'Australia',
#  'United States',
#  'Sweden',
#  'Sweden',
#  'Sweden',
#  'Qatar',
#  'Ireland',
#  'United Kingdom',
#  'United Kingdom',
#  'Spain',
#  'United States',
#  'United States',
#  'Australia',
#  'United States',
#  'South Africa',
#  'South Africa',
#  'Thailand',
#  'Japan',
#  'Brazil',
#  'Qatar',
#  'Ireland',
#  'United Kingdom',
#  'Algeria',
#  'Germany',
#  'United Kingdom',
#  'Spain',
#  'Netherlands',
#  'Australia',
#  'United States',
#  'Qatar',
#  'United States',
#  'United Kingdom',
#  'India',
#  'Switzerland',
#  'Vietnam',
#  'Poland',
#  'United Kingdom',
#  'Singapore',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'United Kingdom',
#  'Switzerland',
#  'United Kingdom',
#  'Spain',
#  'Germany',
#  'United States',
#  'South Africa',
#  'Australia',
#  'United Kingdom',
#  'Greece',
#  'United Kingdom',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'Germany',
#  'United Kingdom',
#  'United States',
#  'United Kingdom',
#  'Malaysia',
#  'United Kingdom',
#  'Kenya',
#  'United Kingdom',
#  'Turkey',
#  'Australia',
#  'Australia',
#  'Thailand',
#  'Czech Republic',
#  'Brazil',
#  'Canada',
#  'Pakistan',
#  'Denmark',
#  'United States',
#  'Germany',
#  'Vietnam',
#  'United States',
#  'Australia',
#  'Norway',
#  'Norway',
#  'Qatar',
#  'New Zealand',
#  'Canada',
#  'Germany',
#  'Qatar',
#  'United States',
#  'Germany',
#  'Germany',
#  'Singapore',
#  'Germany',
#  'Netherlands',
#  'Sweden',
#  'Qatar',
#  'United States',
#  'Canada',
#  'Belgium',
#  'Ukraine',
#  'Thailand',
#  'Germany',
#  'United Kingdom',
#  'United Kingdom',
#  'Netherlands',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'Canada',
#  'Malaysia',
#  'Italy',
#  'Pakistan',
#  'Kuwait',
#  'Philippines',
#  'United States',
#  'Philippines',
#  'Germany',
#  'Italy',
#  'Thailand',
#  'Thailand',
#  'Sweden',
#  'Sweden',
#  'Thailand',
#  'South Africa',
#  'Australia',
#  'United Kingdom',
#  'United Kingdom',
#  'Thailand',
#  'Thailand',
#  'United States',
#  'United States',
#  'Sri Lanka',
#  'Canada',
#  'Spain',
#  'Australia',
#  'United Kingdom',
#  'Brazil',
#  'United States',
#  'Canada',
#  'Australia',
#  'Indonesia',
#  'Indonesia',
#  'Indonesia',
#  'United Arab Emirates',
#  'South Africa',
#  'Australia',
#  'India',
#  'United Kingdom',
#  'Qatar',
#  'Germany',
#  'Belgium',
#  'United States',
#  'Australia',
#  'United States',
#  'Australia',
#  'Denmark',
#  'Hong Kong',
#  'United States',
#  'Qatar',
#  'Romania',
#  'Nigeria',
#  'Pakistan',
#  'Uganda',
#  'United States',
#  'Iraq',
#  'Australia',
#  'Qatar',
#  'United Kingdom',
#  'United Kingdom',
#  'Spain',
#  'United States',
#  'Germany',
#  'Hong Kong',
#  'United States',
#  'Greece',
#  'Canada',
#  'Qatar',
#  'Canada',
#  'United Kingdom',
#  'Spain',
#  'India',
#  'Qatar',
#  'New Zealand',
#  'United Kingdom',
#  'United States',
#  'United Kingdom',
#  'South Africa',
#  'Qatar',
#  'United States',
#  'Canada',
#  'South Africa',
#  'Bermuda',
#  'United Kingdom',
#  'Hong Kong',
#  'Ukraine',
#  'Singapore',
#  'Iran',
#  'Canada',
#  'Myanmar',
#  'United States',
#  'Singapore',
#  'United Arab Emirates',
#  'Australia',
#  'Thailand',
#  'United Kingdom',
#  'Qatar',
#  'United Kingdom',
#  'United States',
#  'Qatar',
#  'Qatar',
#  'Germany',
#  'Singapore',
#  'Ireland',
#  'United States',
#  'Netherlands',
#  'Brunei',
#  'United States',
#  'New Zealand',
#  'Qatar',
#  'South Africa',
#  'United States',
#  'Australia',
#  'Thailand',
#  'Thailand',
#  'Denmark',
#  'Australia',
#  'Malaysia',
#  'China',
#  'Australia',
#  'Philippines',
#  'United States',
#  'Lebanon',
#  'Netherlands',
#  'Thailand',
#  'Netherlands',
#  'United Kingdom',
#  'Thailand',
#  'United States',
#  'Canada',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'Australia',
#  'Sweden',
#  'Australia',
#  'South Africa',
#  'Australia',
#  'Canada',
#  'Canada',
#  'Thailand',
#  'Philippines',
#  'Thailand',
#  'United States',
#  'Canada',
#  'Indonesia',
#  'Kuwait',
#  'Australia',
#  'United Kingdom',
#  'Qatar',
#  'Poland',
#  'Canada',
#  'India',
#  'United States',
#  'Malaysia',
#  'United States',
#  'United Kingdom',
#  'Australia',
#  'United Kingdom',
#  'Thailand',
#  'South Africa',
#  'United States',
#  'Philippines',
#  'Norway',
#  'France',
#  'United States',
#  'United Kingdom',
#  'United Kingdom',
#  'United Kingdom',
#  'Canada',
#  'Hong Kong',
#  'Qatar',
#  'Qatar',
#  'Australia',
#  'India',
#  'Thailand',
#  'United States',
#  'Germany',
#  'United Kingdom',
#  'Malaysia',
#  'Finland',
#  'United States',
#  'Denmark',
#  'Saudi Arabia',
#  'Italy',
#  'United States',
#  'United States',
#  'Canada',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'Denmark',
#  'United States',
#  'United States',
#  'India',
#  'United States',
#  'Turkey',
#  'United Kingdom',
#  'Canada',
#  'Singapore',
#  'Denmark',
#  'United States',
#  'Australia',
#  'Canada',
#  'United Kingdom',
#  'United Arab Emirates',
#  'United States',
#  'United Kingdom',
#  'New Zealand',
#  'United States',
#  'United Kingdom',
#  'Australia',
#  'Germany',
#  'Malaysia',
#  'United Kingdom',
#  'Canada',
#  'Singapore',
#  'United States',
#  'United Kingdom',
#  'Qatar',
#  'Belgium',
#  'Belgium',
#  'Russian Federation',
#  'United Kingdom',
#  'United States',
#  'United Arab Emirates',
#  'United States',
#  'Germany',
#  'Kuwait',
#  'India',
#  'United Kingdom',
#  'United Kingdom',
#  'Sweden',
#  'Australia',
#  'United States',
#  'Hong Kong',
#  'United States',
#  'Kenya',
#  'France',
#  'United Kingdom',
#  'Germany',
#  'United States',
#  'Sweden',
#  'Sweden',
#  'United Arab Emirates',
#  'Romania',
#  'United States',
#  'United States',
#  'United States',
#  'Germany',
#  'Saudi Arabia',
#  'South Africa',
#  'Japan',
#  'India',
#  'Canada',
#  'South Africa',
#  'Qatar',
#  'United States',
#  'Kenya',
#  'Germany',
#  'Iraq',
#  'United Kingdom',
#  'Italy',
#  'Morocco',
#  'United Arab Emirates',
#  'Canada',
#  'United States',
#  'Saudi Arabia',
#  'Australia',
#  'Vietnam',
#  'Nepal',
#  'South Africa',
#  'Qatar',
#  'United States',
#  'United Kingdom',
#  'United Arab Emirates',
#  'Poland',
#  'United Kingdom',
#  'United States',
#  'Switzerland',
#  'United States',
#  'Sweden',
#  'Slovakia',
#  'United Arab Emirates',
#  'Philippines',
#  'Egypt',
#  'Germany',
#  'Germany',
#  'France',
#  'Norway',
#  'United States',
#  'India',
#  'Thailand',
#  'Australia',
#  'United States',
#  'United States',
#  'Nigeria',
#  'Finland',
#  'United States',
#  'India',
#  'United States',
#  'Australia',
#  'India',
#  'Canada',
#  'United States',
#  'Netherlands',
#  'Qatar',
#  'United States',
#  'United States',
#  'United States',
#  'Pakistan',
#  'Ireland',
#  'United States',
#  'Slovenia',
#  'Bulgaria',
#  'Canada',
#  'India',
#  'Kenya',
#  'Pakistan',
#  'Thailand',
#  'United Kingdom',
#  'Pakistan',
#  'United States',
#  'Malaysia',
#  'United Kingdom',
#  'United States',
#  'United States',
#  'Iraq',
#  'United States',
#  'South Korea',
#  'United States',
#  'Indonesia',
#  'Canada',
#  'United Kingdom',
#  'India',
#  'India',
#  'Sweden',
#  'Singapore',
#  'United States',
#  'Oman',
#  'Pakistan',
#  'Portugal',
#  'Sweden',
#  'Qatar',
#  'Qatar',
#  'Germany',
#  'United Kingdom',
#  'Qatar',
#  'Romania',
#  'Australia',
#  'South Korea',
#  'France',
#  'United States',
#  'Estonia',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'Indonesia',
#  'Croatia',
#  'Australia',
#  'Denmark',
#  'United Kingdom',
#  'Japan',
#  'Luxembourg',
#  'United States',
#  'Romania',
#  'United Kingdom',
#  'Bangladesh',
#  'Philippines',
#  'Kenya',
#  'United Kingdom',
#  'Austria',
#  'United States',
#  'Jordan',
#  'Nepal',
#  'South Korea',
#  'Sweden',
#  'Iraq',
#  'Australia',
#  'Iran',
#  'Italy',
#  'Czech Republic',
#  'Singapore',
#  'Sri Lanka',
#  'Lebanon',
#  'Australia',
#  'Australia',
#  'Qatar',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'United Kingdom',
#  'New Zealand',
#  'Indonesia',
#  'United States',
#  'Qatar',
#  'Jordan',
#  'New Zealand',
#  'Qatar',
#  'Dominican Republic',
#  'Spain',
#  'United States',
#  'United Kingdom',
#  'Lebanon',
#  'Australia',
#  'Qatar',
#  'Germany',
#  'United Kingdom',
#  'United Kingdom',
#  'United States',
#  'Finland',
#  'United States',
#  'Germany',
#  'Australia',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'France',
#  'Canada',
#  'Italy',
#  'Australia',
#  'Poland',
#  'Austria',
#  'Switzerland',
#  'United States',
#  'Australia',
#  'Finland',
#  'Canada',
#  'United Kingdom',
#  'Czech Republic',
#  'Australia',
#  'United Kingdom',
#  'Malaysia',
#  'Finland',
#  'United Kingdom',
#  'Lebanon',
#  'Poland',
#  'United Kingdom',
#  'India',
#  'United Kingdom',
#  'Iran',
#  'Vietnam',
#  'Germany',
#  'Australia',
#  'United Kingdom',
#  'United Kingdom',
#  'Romania',
#  'Norway',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'Australia',
#  'Pakistan',
#  'Lebanon',
#  'United States',
#  'Germany',
#  'Norway',
#  'United Kingdom',
#  'Denmark',
#  'Australia',
#  'United States',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'United Kingdom',
#  'United Kingdom',
#  'Australia',
#  'Australia',
#  'Germany',
#  'Oman',
#  'Iceland',
#  'United Kingdom',
#  'Hong Kong',
#  'Hong Kong',
#  'United States',
#  'United Kingdom',
#  'United States',
#  'Australia',
#  'Denmark',
#  'Qatar',
#  'Qatar',
#  'United Kingdom',
#  'Finland',
#  'United Kingdom',
#  'United Kingdom',
#  'Australia',
#  'Italy',
#  'Italy',
#  'Australia',
#  'Canada',
#  'Greece',
#  'Malaysia',
#  'Armenia',
#  'South Africa',
#  'United Kingdom',
#  'Germany',
#  'Iceland',
#  'South Africa',
#  'Australia',
#  'Philippines',
#  'Denmark',
#  'Iceland',
#  'Australia',
#  'Australia',
#  'Germany',
#  'United States',
#  'Indonesia',
#  'Germany',
#  'Pakistan',
#  'United States',
#  'United Kingdom',
#  'United Kingdom',
#  'Australia',
#  'Switzerland',
#  'United Kingdom',
#  'United Kingdom',
#  'Poland',
#  'Denmark',
#  'United Kingdom',
#  'United Kingdom',
#  'Ireland',
#  'Malaysia',
#  'United Kingdom']

# %% [markdown]
# ### **Creating Dataframes for each Airline**

# %%
Set_={'Date':dates0,'Customer Review':reviews0,'Country':country0}
BA_reviews=pd.DataFrame(Set_)

Set_1={'Date':dates1,'Customer Review':reviews1,'Country':country1}
Air_Ind_reviews=pd.DataFrame(Set_1)

Set_2={'Date':dates2,'Customer Review':reviews2,'Country':country2}
Emirates_reviews=pd.DataFrame(Set_2)

Set_3={'Date':dates3,'Customer Review':reviews3,'Country':country3}
Ethihad_reviews=pd.DataFrame(Set_3)

Set_4={'Date':dates4,'Customer Review':reviews4,'Country':country4}
Qatar_reviews=pd.DataFrame(Set_4)

# %%
Emirates_reviews
# Out:
#                    Date                             Customer Review  \
# 0     19th January 2025  “Emirates refused to credit due to policy”
# 1     18th January 2025    “Flying business now feels like economy”
# 2    26th December 2024               "the worst travel experience"
# 3    20th December 2024              "the most horrible experience"
# 4    15th December 2024        “Economy treated as an afterthought”
# ..                  ...                                         ...
# 985   16th January 2018                "I won't fly Emirates again"
# 986   15th January 2018                       "we had no apologies"
# 987   15th January 2018                 extremely poor and chaotic"
# 988   12th January 2018         "standard has declined drastically"
# 989   11th January 2018                     "service was excellent"
#
#                   Country
# 0               Australia
# 1    United Arab Emirates
# 2    United Arab Emirates
# 3               Sri Lanka
# 4    United Arab Emirates
# ..                    ...
# 985        United Kingdom
# 986        United Kingdom
# 987         United States
# 988              Malaysia
# 989  United Arab Emirates
#
# [990 rows x 3 columns]

# %%
Qatar_reviews
# Out:
#                    Date                            Customer Review  \
# 0     14th January 2025    "consistently ranks at or near the top"
# 1     14th January 2025       "noticeable upgrade in meal quality"
# 2      9th January 2025                “Crew always ready to help”
# 3      5th January 2025                  "we were silver members"
# 4      5th January 2025  "the flight with Qatar Airways was great"
# ..                  ...                                        ...
# 985  22nd November 2019                  "service was really good"
# 986  20th November 2019                    "unable to have shower"
# 987  20th November 2019          "So impressed with Qatar Airways"
# 988  20th November 2019               "Staff attentive, efficient"
# 989  19th November 2019                  "service was magnificent"
#
#             Country
# 0           Iceland
# 1           Iceland
# 2            France
# 3         Australia
# 4           Germany
# ..              ...
# 985  United Kingdom
# 986  United Kingdom
# 987         Ireland
# 988        Malaysia
# 989  United Kingdom
#
# [990 rows x 3 columns]

# %% [markdown]
# ### **Fixing the Date Format**

# %%
def date_1(dat):
    dat["Dates"]=pd.to_datetime(dat["Date"],format='mixed')
    dat["Date"]=dat["Dates"]
    dat.drop(columns=["Dates"],inplace=True)
    return dat

data=[Air_Ind_reviews,BA_reviews,Emirates_reviews,Ethihad_reviews,Qatar_reviews]
for df in data:
    df=date_1(df)

# %%
Qatar_reviews
# Out:
#           Date                            Customer Review         Country
# 0   2025-01-14    "consistently ranks at or near the top"         Iceland
# 1   2025-01-14       "noticeable upgrade in meal quality"         Iceland
# 2   2025-01-09                “Crew always ready to help”          France
# 3   2025-01-05                  "we were silver members"        Australia
# 4   2025-01-05  "the flight with Qatar Airways was great"         Germany
# ..         ...                                        ...             ...
# 985 2019-11-22                  "service was really good"  United Kingdom
# 986 2019-11-20                    "unable to have shower"  United Kingdom
# 987 2019-11-20          "So impressed with Qatar Airways"         Ireland
# 988 2019-11-20               "Staff attentive, efficient"        Malaysia
# 989 2019-11-19                  "service was magnificent"  United Kingdom
#
# [990 rows x 3 columns]

# %%
Qatar_reviews["Customer Review"].value_counts().sort_values(ascending=False)
# Out:
# Customer Review
# "Excellent service provided"         3
# "Thank you Qatar Airways"            3
# "exceptional service"                2
# "such an amazing experience"         2
# "everything was perfect"             2
#                                     ..
# "So impressed with Qatar Airways"    1
# "Staff attentive, efficient"         1
# "left me hungry"                     1
# "delayed in Oslo for deicing"        1
# "service was magnificent"            1
# Name: count, Length: 975, dtype: int64

# %% [markdown]
# # NLP

# %%
import re
def clean(text):
    text = re.sub('[^A-Za-z]+', ' ', str(text))
    return text

# Cleaning the text in the review column
data=[Air_Ind_reviews,BA_reviews,Emirates_reviews,Ethihad_reviews,Qatar_reviews]
for df in data:
    df['Cleaned Reviews']=df['Customer Review'].apply(clean)

# %%
Qatar_reviews
# Out:
#           Date                            Customer Review         Country  \
# 0   2025-01-14    "consistently ranks at or near the top"         Iceland
# 1   2025-01-14       "noticeable upgrade in meal quality"         Iceland
# 2   2025-01-09                “Crew always ready to help”          France
# 3   2025-01-05                  "we were silver members"        Australia
# 4   2025-01-05  "the flight with Qatar Airways was great"         Germany
# ..         ...                                        ...             ...
# 985 2019-11-22                  "service was really good"  United Kingdom
# 986 2019-11-20                    "unable to have shower"  United Kingdom
# 987 2019-11-20          "So impressed with Qatar Airways"         Ireland
# 988 2019-11-20               "Staff attentive, efficient"        Malaysia
# 989 2019-11-19                  "service was magnificent"  United Kingdom
#
#                                Cleaned Reviews
# 0       consistently ranks at or near the top
# 1          noticeable upgrade in meal quality
# 2                   Crew always ready to help
# 3                      we were silver members
# 4     the flight with Qatar Airways was great
# ..                                         ...
# 985                   service was really good
# 986                     unable to have shower
# 987           So impressed with Qatar Airways
# 988                 Staff attentive efficient
# 989                   service was magnificent
#
# [990 rows x 4 columns]

# %%
import nltk

"""This punkt tokenizer divides a text into a list of sentences by using an unsupervised algorithm to build a model for abbreviation words,
collocations, and words that start sentences. """

nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
from nltk import pos_tag
nltk.download('stopwords')
from nltk.corpus import stopwords
nltk.download('wordnet')
from nltk.corpus import wordnet
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
#The nltk.corpus package defines a collection of corpus reader classes, which can be used to access the contents of a diverse set of corpora.
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger_eng')

# POS tagger dictionary
pos_dict = {'J':wordnet.ADJ, 'V':wordnet.VERB, 'N':wordnet.NOUN, 'R':wordnet.ADV}
def token_stop_pos(text):
    tags = pos_tag(word_tokenize(text))
    newlist = []
    for word, tag in tags:
        if word.lower() not in set(stopwords.words('english')):
          newlist.append(tuple([word, pos_dict.get(tag[0])]))
    return newlist

for df in data:
    df['POS tagged']=df['Cleaned Reviews'].apply(token_stop_pos)
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.

# %%
Qatar_reviews.head(6)
# Out:
#         Date                            Customer Review    Country  \
# 0 2025-01-14    "consistently ranks at or near the top"    Iceland
# 1 2025-01-14       "noticeable upgrade in meal quality"    Iceland
# 2 2025-01-09                “Crew always ready to help”     France
# 3 2025-01-05                  "we were silver members"   Australia
# 4 2025-01-05  "the flight with Qatar Airways was great"    Germany
# 5 2025-01-02              "pretty disappointing flight"    Germany
#
#                              Cleaned Reviews  \
# 0     consistently ranks at or near the top
# 1        noticeable upgrade in meal quality
# 2                 Crew always ready to help
# 3                    we were silver members
# 4   the flight with Qatar Airways was great
# 5               pretty disappointing flight
#
#                                           POS tagged
# 0  [(consistently, r), (ranks, v), (near, None), ...
# 1  [(noticeable, a), (upgrade, n), (meal, n), (qu...
# 2    [(Crew, n), (always, r), (ready, v), (help, v)]
# 3                        [(silver, a), (members, n)]
# 4  [(flight, n), (Qatar, n), (Airways, n), (great...
# 5     [(pretty, r), (disappointing, a), (flight, n)]

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
def lemmatize(pos_data):
    lemma_rew = " "
    for word, pos in pos_data:
     if not pos:
        lemma = word
        lemma_rew = lemma_rew + " " + lemma
     else:
        lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
        lemma_rew = lemma_rew + " " + lemma
    return lemma_rew

for df in data:
    df['Lemma']=df['POS tagged'].apply(lemmatize)
Emirates_reviews.head()
# Out:
#         Date                             Customer Review  \
# 0 2025-01-19  “Emirates refused to credit due to policy”
# 1 2025-01-18    “Flying business now feels like economy”
# 2 2024-12-26               "the worst travel experience"
# 3 2024-12-20              "the most horrible experience"
# 4 2024-12-15        “Economy treated as an afterthought”
#
#                 Country                             Cleaned Reviews  \
# 0             Australia   Emirates refused to credit due to policy
# 1  United Arab Emirates     Flying business now feels like economy
# 2  United Arab Emirates                the worst travel experience
# 3             Sri Lanka               the most horrible experience
# 4  United Arab Emirates         Economy treated as an afterthought
#
#                                           POS tagged  \
# 0  [(Emirates, n), (refused, v), (credit, n), (du...
# 1  [(Flying, v), (business, n), (feels, v), (like...
# 2         [(worst, a), (travel, n), (experience, n)]
# 3                   [(horrible, a), (experience, n)]
# 4    [(Economy, r), (treated, v), (afterthought, n)]
#
#                                  Lemma
# 0    Emirates refuse credit due policy
# 1    Flying business feel like economy
# 2                bad travel experience
# 3                  horrible experience
# 4           Economy treat afterthought

# %%
Air_Ind_reviews.to_csv("/content/sample_data/Air_Ind_Ratings.csv")
BA_reviews.to_csv("/content/sample_data/BA_Ratings.csv")
Emirates_reviews.to_csv("/content/sample_data/Emirates_Ratings.csv")
Ethihad_reviews.to_csv("/content/sample_data/Ethihad_Ratings.csv")
Qatar_reviews.to_csv("/content/sample_data/Qatar_Ratings.csv")
